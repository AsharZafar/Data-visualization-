# %%
#Data cleaning

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.head()
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        9.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain

# %%
df1=df.copy()
df1.set_index("day",inplace=True)

# %%
df.isnull().sum()
# Out:
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df.fillna(0)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# It is nor right to use 0 insted of null values insted u could just use mean and median

# %%
df1.fillna({

"temperature":df.temperature.mean(),
"windspeed"  :df.windspeed.mean(),
"Event"       :"No event"
})
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01        32.00       6.00    Rain
# 2017-01-04        33.22       9.00   Sunny
# 2017-01-05        28.00       8.42    Snow
# 2017-01-06        33.22       7.00     NaN
# 2017-01-07        32.00       8.42    Rain
# 2017-01-08        33.22       8.42   Sunny
# 2017-01-09        33.22       8.42     NaN
# 2017-01-10        34.10       8.10  Cloudy
# 2017-01-11        40.00      12.00   Sunny

# %%
#another methode is to use previous value

# %%
df2=df.copy()
df2.fillna(method="ffill")

# %%
import numpy as np
import pandas as pd
Df=pd.read_csv("/content/weather_data.csv")

# %%
Df.head()
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017           32          6      Rain
# 1  1/2/2017       -99999          7     Sunny
# 2  1/3/2017           28     -99999      Snow
# 3  1/4/2017       -99999          7  no event
# 4  1/5/2017           32     -99999      Rain

# %%
Df.replace([-99999,-8888],np.nan)
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          NaN        7.0     Sunny
# 2  1/3/2017         28.0        NaN      Snow
# 3  1/4/2017          NaN        7.0  no event
# 4  1/5/2017         32.0        NaN      Rain
# 5  1/6/2017         31.0        2.0     Sunny
# 6  1/6/2017         34.0   -88888.0  no event
