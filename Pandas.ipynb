# %%
import pandas as pd
df=pd.read_csv("/content/movies.csv")
df.head()

# %%
df["industry"].unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
# lest say that we want to use only 2 columsn for our data analysis
df_new=df[["title","imdb_rating"]]
df_new
# Out:
#                                           title  imdb_rating
# 0                               Pather Panchali          8.3
# 1   Doctor Strange in the Multiverse of Madness          7.0
# 2                         Thor: The Dark World           6.8
# 3                               Thor: Ragnarok           7.9
# 4                       Thor: Love and Thunder           6.8
# 5                      The Shawshank Redemption          9.3
# 6                                  Interstellar          8.6
# 7                      The Pursuit of Happyness          8.0
# 8                                     Gladiator          8.5
# 9                                       Titanic          7.9
# 10                        It's a Wonderful Life          8.6
# 11                                       Avatar          7.8
# 12                                The Godfather          9.2
# 13                              The Dark Knight          9.0
# ...

# %%
# if you want to se movies before 2000 and 2010

df[(df.release_year>2000) & (df.release_year>2010)]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 6                                  Interstellar  Hollywood          2014
# 16                                     Parasite  Hollywood          2019
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
# 24                             Bajirao Mastani   Bollywood          2015
# 27                                           PK  Bollywood          2014
# ...

# %%
df[df.studio=="Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
# if you want to prnt maximum and min ratings use or operator |
df[(df.imdb_rating==df.imdb_rating.max()) | (df.imdb_rating==df.imdb_rating.max())]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
# topint age a movie

df["age"]=df["release_year"].apply(lambda x: 2023-x)

df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   68
# 1      USD  English    1
# ...

# %%
df["profit"]=df.apply(lambda x: x['revenue']-x['budget'], axis=1)

# %%
df["profit"] = df.apply(lambda row: row['revenue'] - row['budget'], axis=1)

# %%
# index operation

df.set_index("title",inplace=True)

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
#locating index

df.loc["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    68
# profit                            30000.0
# Name: Pather Panchali, dtype: object

# %%
df.reset_index

# %% [markdown]
# **#Read and weite in csv using pandas

# %%
df=pd.read_csv("/content/stock_data.csv")
df.head()
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani

# %%
df=pd.read_csv("/content/stock_data.csv",skiprows=1)
df.head()
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd

# %%
# it will drop all na and not availabe value in all columns
df = pd.read_csv("/content/stock_data.csv", header=1, na_values=["not available","n.a.", -1])
df.head()
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df["pe"]=df["revenue"]/df["price"]
df.head()
# Out:
#   tickers    eps  revenue   price         people        pe
# 0   GOOGL  27.82     87.0   845.0     larry page  0.102959
# 1     WMT   4.61    484.0    65.0            NaN  7.446154
# 2    MSFT    NaN     85.0    64.0     bill gates  1.328125
# 3    RIL     NaN     50.0  1023.0  mukesh ambani  0.048876
# 4    TATA   5.60      NaN     NaN     ratan tata       NaN

# %% [markdown]
# **# Reading excel files**

# %%
#read only first 2 sheets
df_movies=pd.read_excel("/content/movies_db.xlsx","movies")

# %%
df.head()
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5
# 3          2017          7.9  Marvel Studios            5
# 4          2022          6.8  Marvel Studios            5

# %%
#Change the currency

# %%
#read only first 2 sheets
df_financials=pd.read_excel("/content/movies_db.xlsx","financials")
df_financials.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions       $$
# 3       104   180.0    854.0  Millions  Dollars
# 4       105   250.0    670.0  Millions      USD

# %%
#read only first 2 sheets
def standarized_currency(curr):

    if curr=="$$" or curr=="Dollars":

        return "USD"
    return curr

df_financials2=pd.read_excel("/content/movies_db.xlsx","financials",converters={

"currency" : standarized_currency

})

df_financials2.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD
# 3       104   180.0    854.0  Millions      USD
# 4       105   250.0    670.0  Millions      USD

# %%
df_financials2.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD
# 3       104   180.0    854.0  Millions      USD
# 4       105   250.0    670.0  Millions      USD

# %%
# suppose if you want to meege 2 sheets  and show in one file and save it to one csv or excel file

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_financials2.head(3)
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD

# %%
df_merged=pd.merge(df_financials2,df_movies,on="movie_id")

# %%
df_merged.head(3)
# Out:
#    movie_id  budget  revenue      unit currency  \
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD
#
#                                          title   industry  release_year  \
# 0                             K.G.F: Chapter 2  Bollywood          2022
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating          studio  language_id
# 0          8.4   Hombale Films            3
# 1          7.0  Marvel Studios            5
# 2          6.8  Marvel Studios            5

# %%
df_stocks=pd.DataFrame({

"price"   :[23,34,4,1],
"company" :["apple","kababjees","kfc","gulahmed"],
"Value"   :[0,0,0,0]
})
df_stocks.head()
# Out:
#    price    company  Value
# 0     23      apple      0
# 1     34  kababjees      0
# 2      4        kfc      0
# 3      1   gulahmed      0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "AsharZafar"
# !git config --global user.email "asharcolab@gmail.com"

# %%
# !git clone https://github.com/AsharZafar/Data-visualization-.git
# Out:
# Cloning into 'Data-visualization-'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !mv /path_to_your_notebook/your_notebook.ipynb /content/Data-visualization-/
# Out:
# mv: cannot stat '/path_to_your_notebook/your_notebook.ipynb': No such file or directory
